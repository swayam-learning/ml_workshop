# %%
import pandas as pd
pd.set_option("display.max_column",None)

# %%
df = pd.read_csv("Uncleaned_DS_jobs.csv")
df
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df["Job Description"]=df["Job Description"].str.replace("\n","")

# %%
df["Job Description"]
# Out:
# 0      DescriptionThe Senior Data Scientist is respon...
# 1      Secure our Nation, Ignite your FutureJoin the ...
# 2      OverviewAnalysis Group is one of the largest i...
# 3      JOB DESCRIPTION:Do you have a passion for Data...
# 4      Data ScientistAffinity Solutions / Marketing C...
#                              ...
# 667    SummaryWe’re looking for a data scientist to d...
# 668    Job DescriptionBecome a thought leader within ...
# 669    Join a thriving company that is changing the w...
# 670    100 Remote Opportunity As an AINLP Data Scient...
# 671    DescriptionThe Data Scientist will be part of ...
# Name: Job Description, Length: 672, dtype: object

# %%
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
df["Salary Estimate"]=df["Salary Estimate"].str.replace("$","")

# %%
df["Salary Estimate"]=df["Salary Estimate"].str.replace("K","")

# %%
df.head()
# Out:
#    index          Job Title           Salary Estimate  \
# 0      0  Sr Data Scientist  137-171 (Glassdoor est.)
# 1      1     Data Scientist  137-171 (Glassdoor est.)
# 2      2     Data Scientist  137-171 (Glassdoor est.)
# 3      3     Data Scientist  137-171 (Glassdoor est.)
# 4      4     Data Scientist  137-171 (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
df["Salary Estimate"]=df["Salary Estimate"].str.replace("(Glassdoor est.)","")

# %%
df.head()
# Out:
#    index          Job Title Salary Estimate  \
# 0      0  Sr Data Scientist        137-171
# 1      1     Data Scientist        137-171
# 2      2     Data Scientist        137-171
# 3      3     Data Scientist        137-171
# 4      4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# ...

# %%
df["min_salary"] = df["Salary Estimate"][0][0:3]

# %%
df["max_salary"] = df["Salary Estimate"][0][4:7]

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# ...

# %%
df["min_salary"] = df["min_salary"].astype(int)

# %%
df["max_salary"] = df["max_salary"].astype(int)

# %%
df["avg_salary"] = (df["min_salary"]+df["max_salary"])/2

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# ...

# %%
df["Company Name"]=df["Company Name"].str.split('\n').str[0]

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df.drop("Competitors",axis=1,inplace=True)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df["avg_salary"]=df["avg_salary"].astype(int)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df["Job State"] = df["Location"].str.split(",").str[-1]

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df["Same State"] = (df["Location"].str.split(",").str[0]) == (df["Headquarters"].str.split(",").str[0])

# %%
df["Same State"]=df["Same State"].astype(int)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df["Company Age"] = 2024- df["Founded"].astype(int)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
import re
languages = ['Python','Excel','Hadoop', 'Spark', 'AWS','Tableau', 'Big_Data']
pattern = r'\b(?:' + '|'.join(languages) + r')\b'
df['programming_languages'] = df['Job Description'].apply(lambda x: ', '.join(re.findall(pattern, x, flags=re.IGNORECASE)))

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df.drop_duplicates(subset="programming_languages")
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 630     Data Scientist         87-141
# 641     Data Scientist         92-155
# 642      Data Engineer         92-155
# 663     Data Scientist        105-167
# 667     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    DescriptionThe Senior Data Scientist is respon...     3.1
# 1    Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2    OverviewAnalysis Group is one of the largest i...     3.8
# 3    JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4    Data ScientistAffinity Solutions / Marketing C...     2.9
# ..                                                 ...     ...
# ...

# %%
# extract name of technologies from job description column
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df['hadoop'] = df['Job Description'].apply(lambda x: 1 if 'hadoop' in x.lower() else 0)
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df['tableau'] = df['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)
df['big_data'] = df['Job Description'].apply(lambda x: 1 if 'big_data' in x.lower() else 0)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df.groupby("Job Title")["Job Title"].value_counts()
# Out:
# Job Title
# (Sr.) Data Scientist -                                     2
# AI Data Scientist                                          1
# AI Ops Data Scientist                                      3
# AI/ML - Machine Learning Scientist, Siri Understanding     1
# Analytics - Business Assurance Data Analyst                3
#                                                           ..
# Statistical Scientist                                      1
# Tableau Data Engineer 20-0117                              1
# VP, Data Science                                           2
# Vice President, Biometrics and Clinical Data Management    1
# Weapons and Sensors Engineer/Scientist                     2
# Name: count, Length: 172, dtype: int64

# %%
df["Job Title"].values
# Out:
# array(['Sr Data Scientist', 'Data Scientist', 'Data Scientist',
#        'Data Scientist', 'Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert', 'Data Scientist',
#        'Staff Data Scientist - Analytics', 'Data Scientist',
#        'Data Scientist', 'Data Scientist',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Data Scientist', 'Experienced Data Scientist',
#        'Data Scientist - Contract', 'Data Scientist', 'Data Analyst II',
#        'Medical Lab Scientist', 'Data Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights', 'Data Scientist',
#        'Data Scientist', 'Data Scientist - Risk',
#        'Data Scientist-Human Resources', 'Data Scientist',
#        'Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert', 'Data Scientist',
# ...

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist    455
# na                 69
# analyst            55
# data engineer      47
# mle                36
# manager             7
# director            3
# Name: count, dtype: int64

# %%
df.drop("programming_languages",axis=1,inplace=True)

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  DescriptionThe Senior Data Scientist is respon...     3.1
# 1  Secure our Nation, Ignite your FutureJoin the ...     4.2
# 2  OverviewAnalysis Group is one of the largest i...     3.8
# 3  JOB DESCRIPTION:Do you have a passion for Data...     3.5
# 4  Data ScientistAffinity Solutions / Marketing C...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...
