# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
insurance = pd.read_csv("insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
bmi_data = insurance["bmi"]
charges_data = insurance["charges"]

# %%
age_data = insurance["age"]
charges_data = insurance["charges"]

# %%
age = np.array(age_data).reshape(-1,1)
charges = np.array(charges_data).reshape(-1,1)

# %%
bmi = np.array(bmi_data).reshape(-1,1)
charges = np.array(charges_data).reshape(-1,1)

# %%
linreg = LinearRegression()
linreg.fit(age,charges)
# Out:
# LinearRegression()

# %%
linreg = LinearRegression()
linreg.fit(bmi,charges)
# Out:
# LinearRegression()

# %%
prediction2 = linreg.predict(bmi)

# %%
prediction = linreg.predict(age)

# %%
from matplotlib import pyplot as plt
plt.scatter(age,charges, color="green")
plt.plot(age,prediction, color="red")
plt.title("Linear Regression")
plt.xlabel("Age")
plt.ylabel("Charges")
# Out:
# Text(0, 0.5, 'Charges')

# %%
from matplotlib import pyplot as plt
plt.scatter(bmi,charges, color="green")
plt.plot(bmi,prediction2, color="red")
plt.title("Linear Regression")
plt.xlabel("Age")
plt.ylabel("Charges")
# Out:
# Text(0, 0.5, 'Charges')

# %%
corr = insurance[["age","bmi","charges"]].corr()

# %%
print(corr)
# Out:
#               age       bmi   charges
# age      1.000000  0.109272  0.299008
# bmi      0.109272  1.000000  0.198341
# charges  0.299008  0.198341  1.000000

# %%
insurance["smoker"] = insurance["smoker"].apply(lambda x:1 if x=="yes" else 0)

# %%
insurance
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Smoker vs Charges correlation

# %%
corr = insurance[["age","bmi","charges","smoker"]].corr()

# %%
print(corr)
# Out:
#               age       bmi   charges    smoker
# age      1.000000  0.109272  0.299008 -0.025019
# bmi      0.109272  1.000000  0.198341  0.003750
# charges  0.299008  0.198341  1.000000  0.787251
# smoker  -0.025019  0.003750  0.787251  1.000000

# %%
smoker_data = insurance["smoker"]
charges_data = insurance["charges"]

# %%
smoker = np.array(smoker_data).reshape(-1,1)
charges = np.array(charges_data).reshape(-1,1)

# %%
linreg = LinearRegression()
linreg.fit(smoker,charges)
# Out:
# LinearRegression()

# %%
prediction = linreg.predict(smoker)

# %%
from matplotlib import pyplot as plt
plt.scatter(smoker,charges, color="green")
plt.plot(smoker,prediction, color="red")
plt.title("Linear Regression")
plt.xlabel("smoker")
plt.ylabel("Charges")
# Out:
# Text(0, 0.5, 'Charges')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(bmi,charges,test_size=0.4,random_state=42)
print("Shape of X_train: ",X_train.shape)
print("Shape of X_test: ",X_test.shape)
print("Shape of Y_train: ",Y_train.shape)
print("Shape of Y_test: ",Y_test.shape)
# Out:
# Shape of X_train:  (802, 1)
# Shape of X_test:  (536, 1)
# Shape of Y_train:  (802, 1)
# Shape of Y_test:  (536, 1)

# %%
linreg = LinearRegression()
linreg.fit(age,charges)
# Out:
# LinearRegression()

# %%
prediction = linreg.predict()

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(bmi,Y_pred)

print(f"the accuracy is : {accuracy*100:.0f}%")

# %%
Y_pred = linreg.predict(bmi)

print("The predicted Y is: ",Y_pred)

print("The avtual Y is: ",Y_test)
# Out:
# The predicted Y is:  [[10356.34606687]
#  [11869.17783844]
#  [11670.73142207]
#  ...
#  [12662.96350394]
#  [ 9815.12856767]
#  [10657.88153071]]
# The avtual Y is:  [[ 9095.06825 ]
#  [ 5272.1758  ]
#  [29330.98315 ]
#  [ 9301.89355 ]
#  [33750.2918  ]
#  [ 4536.259   ]
#  [ 2117.33885 ]
#  [14210.53595 ]
#  [ 3732.6251  ]
#  [10264.4421  ]
#  [18259.216   ]
#  [ 7256.7231  ]
#  [ 3947.4131  ]
#  [46151.1245  ]
#  [48673.5588  ]
#  [44202.6536  ]
#  [ 9800.8882  ]
#  [42969.8527  ]
#  [ 8233.0975  ]
#  [21774.32215 ]
#  [ 5080.096   ]
#  [ 7441.501   ]
#  [ 1256.299   ]
#  [ 2755.02095 ]
#  [11085.5868  ]
#  [10923.9332  ]
#  [12644.589   ]
#  [18804.7524  ]
#  [ 9715.841   ]
#  [ 1131.5066  ]
#  [15828.82173 ]
#  [11842.62375 ]
#  [ 2020.5523  ]
#  [ 5693.4305  ]
#  [ 2904.088   ]
#  [ 7448.40395 ]
#  [ 2597.779   ]
#  [ 7337.748   ]
#  [23887.6627  ]
#  [38709.176   ]
#  [ 4687.797   ]
#  [ 2643.2685  ]
#  [11674.13    ]
#  [12124.9924  ]
#  [ 4889.9995  ]
#  [12333.828   ]
# ...

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(linreg,bmi,charges,cv=5)

print("Cross Validation Score:",cv_scores)
print("Average of Cross validation Score",cv_scores.mean())
# Out:
# Cross Validation Score: [0.02686959 0.0307745  0.04511717 0.04444618 0.04237   ]
# Average of Cross validation Score 0.03791548715454536
